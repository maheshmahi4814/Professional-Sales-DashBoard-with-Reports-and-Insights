# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\mahes\OneDrive\Documents\Custom Office Templates\amazon_ecommerce_advanced_40000.csv")

# %%
df.shape
# Out:
# (40000, 22)

# %%
df.describe()
# Out:
#            Quantity  Unit Price (₹)  Discount (%)  Total Amount (₹)  \
# count  40000.000000    40000.000000  40000.000000      40000.000000
# mean       2.998425    15122.380982     15.015875      38568.538086
# std        1.416694     8633.277368     10.004143      31030.252481
# min        1.000000      149.070000      0.000000        104.350000
# 25%        2.000000     7631.435000      5.000000      13995.755000
# 50%        3.000000    15126.495000     15.000000      29722.635000
# 75%        4.000000    22662.667500     25.000000      56700.190000
# max        5.000000    29999.640000     30.000000     149977.500000
#
#        Customer Rating  Seller Rating  Delivery Days    Profit (₹)
# count     40000.000000   40000.000000   36775.000000  40000.000000
# mean          4.155700       4.251475       5.701509   6362.715989
# std           1.031254       0.433747       3.164558   6420.338972
# min           1.000000       3.500000       0.000000      6.320000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          40000 non-null  object
#  1   Customer ID       40000 non-null  object
#  2   Product Name      40000 non-null  object
#  3   Category          40000 non-null  object
#  4   Quantity          40000 non-null  int64
#  5   Unit Price (₹)    40000 non-null  float64
#  6   Discount (%)      40000 non-null  int64
#  7   Total Amount (₹)  40000 non-null  float64
#  8   Order Date        40000 non-null  object
#  9   Payment Method    40000 non-null  object
#  10  Delivery Status   40000 non-null  object
#  11  Shipping Partner  40000 non-null  object
#  12  City              40000 non-null  object
#  13  State             40000 non-null  object
#  14  Customer Rating   40000 non-null  int64
#  15  Review Text       32738 non-null  object
# ...

# %%
df.drop('Review Text',axis = 1, inplace = True)

# %%
df.drop('Return Reason' , axis = 1 , inplace = True)

# %%
duplicated_rows = df[df.duplicated()]
print(duplicated_rows)
# Out:
# Empty DataFrame
# Columns: [Order ID, Customer ID, Product Name, Category, Quantity, Unit Price (₹), Discount (%), Total Amount (₹), Order Date, Payment Method, Delivery Status, Shipping Partner, City, State, Customer Rating, Seller Rating, Delivery Days, Season, Profit (₹), Region]
# Index: []

# %%
unique_counts = df.nunique()
print(unique_counts)
# Out:
# Order ID            40000
# Customer ID         39209
# Product Name           20
# Category                5
# Quantity                5
# Unit Price (₹)      39718
# Discount (%)            7
# Total Amount (₹)    39910
# Order Date            334
# Payment Method          5
# Delivery Status         4
# Shipping Partner        5
# City                    8
# State                   7
# Customer Rating         5
# Seller Rating         151
# Delivery Days          16
# Season                  3
# Profit (₹)          39333
# Region                  4
# dtype: int64

# %%
df.describe(include = 'all')
# Out:
#           Order ID Customer ID  Product Name     Category      Quantity  \
# count        40000       40000         40000        40000  40000.000000
# unique       40000       39209            20            5           NaN
# top     AMZA200000  CUST821176  Laptop Stand  Accessories           NaN
# freq             1           3          2056         8032           NaN
# mean           NaN         NaN           NaN          NaN      2.998425
# std            NaN         NaN           NaN          NaN      1.416694
# min            NaN         NaN           NaN          NaN      1.000000
# 25%            NaN         NaN           NaN          NaN      2.000000
# 50%            NaN         NaN           NaN          NaN      3.000000
# 75%            NaN         NaN           NaN          NaN      4.000000
# max            NaN         NaN           NaN          NaN      5.000000
#
#         Unit Price (₹)  Discount (%)  Total Amount (₹)  Order Date  \
# ...

# %%
df['Quantity'].median()
# Out:
# np.float64(3.0)

# %%
df['Unit Price (₹)'].median()
# Out:
# np.float64(15126.494999999999)

# %%
df['Discount (%)'].median()
# Out:
# np.float64(15.0)

# %%
df['Total Amount (₹)'].median()
# Out:
# np.float64(29722.635000000002)

# %%
df['Customer Rating'].median()
# Out:
# np.float64(4.0)

# %%
df['Seller Rating'].median()
# Out:
# np.float64(4.25)

# %%
df['Delivery Days'].median()
# Out:
# np.float64(6.0)

# %%
df['Delivery Days'].median()
# Out:
# np.float64(6.0)

# %%
df['Profit (₹)'].median()
# Out:
# np.float64(4108.17)

# %%
df['Quantity'].var()
# Out:
# np.float64(2.007022694942373)

# %%
df['Unit Price (₹)'].var()
# Out:
# np.float64(74533478.11705871)

# %%
df['Discount (%)'].var()
# Out:
# np.float64(100.08287505625142)

# %%
df['Total Amount (₹)'].var()
# Out:
# np.float64(962876569.052871)

# %%
df['Customer Rating'].var()
# Out:
# np.float64(1.0634840971024278)

# %%
df['Seller Rating'].var()
# Out:
# np.float64(0.18813654455105128)

# %%
df['Delivery Days'].var()
# Out:
# np.float64(10.014425035096878)

# %%
df['Profit (₹)'].var()
# Out:
# np.float64(41220752.52031798)

# %%
Q1 = df['Quantity'].quantile(0.25)
Q3 = df['Quantity'].quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# 2.0

# %%
Q1 = df['Unit Price (₹)'].quantile(0.25)
Q3 = df['Unit Price (₹)'].quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# 15031.2325

# %%
Q1 = df['Discount (%)'].quantile(0.25)
Q3 = df['Discount (%)'].quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# 20.0

# %%
Q1 = df['Total Amount (₹)'].quantile(0.25)
Q3 = df['Total Amount (₹)'].quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# 42704.435000000005

# %%
Q1 = df['Customer Rating'].quantile(0.25)
Q3 = df['Customer Rating'].quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# 1.0

# %%
Q1 = df['Seller Rating'].quantile(0.25)
Q3 = df['Seller Rating'].quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# 0.75

# %%
Q1 = df['Delivery Days'].quantile(0.25)
Q3 = df['Delivery Days'].quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# 5.0

# %%
Q1 = df['Profit (₹)'].quantile(0.25)
Q3 = df['Profit (₹)'].quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# 7188.924999999999

# %%
sns.boxplot(x = 'Quantity' , data = df)
# Out:
# <Axes: xlabel='Quantity'>

# %%
sns.boxplot(x = 'Unit Price (₹)' , data = df)
# Out:
# <Axes: xlabel='Unit Price (₹)'>

# %%
sns.boxplot(x = 'Discount (%)' , data = df)
# Out:
# <Axes: xlabel='Discount (%)'>

# %%
sns.boxplot(x = 'Total Amount (₹)' , data = df)
# Out:
# <Axes: xlabel='Total Amount (₹)'>

# %%
sns.boxplot(x = 'Customer Rating' , data = df)
# Out:
# <Axes: xlabel='Customer Rating'>

# %%
sns.boxplot(x = 'Seller Rating' , data = df)
# Out:
# <Axes: xlabel='Seller Rating'>

# %%
sns.boxplot(x = 'Delivery Days' , data = df)
# Out:
# <Axes: xlabel='Delivery Days'>

# %%
sns.boxplot(x = 'Profit (₹)' , data = df)
# Out:
# <Axes: xlabel='Profit (₹)'>

# %%
df['Quantity'].skew() # data here normally distributed
# Out:
# np.float64(0.00631627285858811)

# %%
df['Quantity'].kurt()  # ok done
# Out:
# np.float64(-1.3026785922163127)

# %%
df['Unit Price (₹)'].skew()# ok done
# Out:
# np.float64(-0.005928138484599345)

# %%
df['Unit Price (₹)'].kurt() #ok done
# Out:
# np.float64(-1.2102467389227574)

# %%
df['Discount (%)'].skew() #ok done
# Out:
# np.float64(-0.0077728757804629315)

# %%
df['Discount (%)'].kurt() #ok done
# Out:
# np.float64(-1.2547525508211657)

# %%
df['Total Amount (₹)'].skew() #needs to be capped and transformation
# Out:
# np.float64(0.9871518511753137)

# %%
df['Total Amount (₹)'].kurt() #needs to be capped and transformation
# Out:
# np.float64(0.3221485818518852)

# %%
df['Customer Rating'].skew() # needs to be treated outliers and transformation
# Out:
# np.float64(-1.2408502751578707)

# %%
df['Customer Rating'].kurt() # needs to be treated outliers and capping ,transformation
# Out:
# np.float64(1.016409119547986)

# %%
df['Seller Rating'].skew()
# Out:
# np.float64(-0.009594573441531596)

# %%
df['Seller Rating'].kurt()
# Out:
# np.float64(-1.2004745854147807)

# %%
df['Delivery Days'].skew() #needs to be filled missed values
# Out:
# np.float64(0.258026469889041)

# %%
df['Delivery Days'].kurt() #ok
# Out:
# np.float64(-0.6073136023224355)

# %%
df['Profit (₹)'].skew() # needs to be treated outliers and capped , transformation
# Out:
# np.float64(1.6824360703183097)

# %%
df['Profit (₹)'].kurt()  #need to apply transformation
# Out:
# np.float64(3.038665992085888)

# %%
sns.histplot(x = 'Profit (₹)' , data = df)
# Out:
# <Axes: xlabel='Profit (₹)', ylabel='Count'>

# %%
df['Profit (₹)'].plot(kind = 'kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Quantity'].plot(kind = 'kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Unit Price (₹)'].plot(kind = 'kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Discount (%)'].plot(kind = 'kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Total Amount (₹)'].plot(kind = 'kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Customer Rating'].plot(kind = 'kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Seller Rating'].plot(kind = 'kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Delivery Days'].plot(kind = 'kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Profit (₹)'].plot(kind = 'kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df.describe()
# Out:
#            Quantity  Unit Price (₹)  Discount (%)  Total Amount (₹)  \
# count  40000.000000    40000.000000  40000.000000      40000.000000
# mean       2.998425    15122.380982     15.015875      38568.538086
# std        1.416694     8633.277368     10.004143      31030.252481
# min        1.000000      149.070000      0.000000        104.350000
# 25%        2.000000     7631.435000      5.000000      13995.755000
# 50%        3.000000    15126.495000     15.000000      29722.635000
# 75%        4.000000    22662.667500     25.000000      56700.190000
# max        5.000000    29999.640000     30.000000     149977.500000
#
#        Customer Rating  Seller Rating  Delivery Days    Profit (₹)
# count     40000.000000   40000.000000   36775.000000  40000.000000
# mean          4.155700       4.251475       5.701509   6362.715989
# std           1.031254       0.433747       3.164558   6420.338972
# min           1.000000       3.500000       0.000000      6.320000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          40000 non-null  object
#  1   Customer ID       40000 non-null  object
#  2   Product Name      40000 non-null  object
#  3   Category          40000 non-null  object
#  4   Quantity          40000 non-null  int64
#  5   Unit Price (₹)    40000 non-null  float64
#  6   Discount (%)      40000 non-null  int64
#  7   Total Amount (₹)  40000 non-null  float64
#  8   Order Date        40000 non-null  object
#  9   Payment Method    40000 non-null  object
#  10  Delivery Status   40000 non-null  object
#  11  Shipping Partner  40000 non-null  object
#  12  City              40000 non-null  object
#  13  State             40000 non-null  object
#  14  Customer Rating   40000 non-null  int64
#  15  Review Text       32738 non-null  object
# ...

# %%
df['Delivery Days'] = df['Delivery Days'].fillna(df['Delivery Days'].median())

# %%
df.isnull().sum()
# Out:
# Order ID                0
# Customer ID             0
# Product Name            0
# Category                0
# Quantity                0
# Unit Price (₹)          0
# Discount (%)            0
# Total Amount (₹)        0
# Order Date              0
# Payment Method          0
# Delivery Status         0
# Shipping Partner        0
# City                    0
# State                   0
# Customer Rating         0
# Review Text          7262
# Seller Rating           0
# Return Reason       35963
# Delivery Days           0
# Season                  0
# Profit (₹)              0
# Region                  0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          40000 non-null  object
#  1   Customer ID       40000 non-null  object
#  2   Product Name      40000 non-null  object
#  3   Category          40000 non-null  object
#  4   Quantity          40000 non-null  int64
#  5   Unit Price (₹)    40000 non-null  float64
#  6   Discount (%)      40000 non-null  int64
#  7   Total Amount (₹)  40000 non-null  float64
#  8   Order Date        40000 non-null  object
#  9   Payment Method    40000 non-null  object
#  10  Delivery Status   40000 non-null  object
#  11  Shipping Partner  40000 non-null  object
#  12  City              40000 non-null  object
#  13  State             40000 non-null  object
#  14  Customer Rating   40000 non-null  int64
#  15  Seller Rating     40000 non-null  float64
# ...

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          40000 non-null  object
#  1   Customer ID       40000 non-null  object
#  2   Product Name      40000 non-null  object
#  3   Category          40000 non-null  object
#  4   Quantity          40000 non-null  int64
#  5   Unit Price (₹)    40000 non-null  float64
#  6   Discount (%)      40000 non-null  int64
#  7   Total Amount (₹)  40000 non-null  float64
#  8   Order Date        40000 non-null  datetime64[ns]
#  9   Payment Method    40000 non-null  object
#  10  Delivery Status   40000 non-null  object
#  11  Shipping Partner  40000 non-null  object
#  12  City              40000 non-null  object
#  13  State             40000 non-null  object
#  14  Customer Rating   40000 non-null  int64
#  15  Review Text       32738 non-null  object
# ...

# %%
sns.boxplot(x = 'Total Amount (₹)', data = df)
# Out:
# <Axes: xlabel='Total Amount (₹)'>

# %%
sns.ecdfplot(x = 'Total Amount (₹)' , data = df)
# Out:
# <Axes: xlabel='Total Amount (₹)', ylabel='Proportion'>

# %%
sns.histplot(x = 'Total Amount (₹)' , data = df)
# Out:
# <Axes: xlabel='Total Amount (₹)', ylabel='Count'>

# %%
Q1 = df['Total Amount (₹)'].quantile(0.25)
Q3 = df['Total Amount (₹)'].quantile(0.75)
IQR = Q3 - Q1
lower_limit = Q1 - (1.5) * IQR
upper_limit = Q3 + (1.5) * IQR
df['Total Amount (₹)'] = np.clip(df['Total Amount (₹)'],lower_limit, upper_limit)

# %%
sns.boxplot(x = 'Total Amount (₹)', data = df)
# Out:
# <Axes: xlabel='Total Amount (₹)'>

# %%
Q1 = df['Profit (₹)'].quantile(0.25)
Q3 = df['Profit (₹)'].quantile(0.75)
IQR = Q3 - Q1
lower_limit = Q1 - 1.5 * IQR
upper_limit = Q3 + 1.5 * IQR
df['Unit Price (₹)'] = np.clip(df['Unit Price (₹)'],lower_limit,upper_limit)

# %%
df.describe()
# Out:
#            Quantity  Unit Price (₹)  Discount (%)  Total Amount (₹)  \
# count  40000.000000    40000.000000  40000.000000      40000.000000
# mean       2.998425    13322.799548     15.015875      38401.187592
# min        1.000000      149.070000      0.000000        104.350000
# 25%        2.000000     7631.435000      5.000000      13995.755000
# 50%        3.000000    15126.495000     15.000000      29722.635000
# 75%        4.000000    19706.607500     25.000000      56700.190000
# max        5.000000    19706.607500     30.000000     120756.842500
# std        1.416694     6517.138714     10.004143      30539.453983
#
#                           Order Date  Customer Rating  Seller Rating  \
# count                          40000     40000.000000   40000.000000
# mean   2025-07-24 17:01:51.600000256         4.155700       4.251475
# min              2025-01-01 00:00:00         1.000000       3.500000
# 25%              2025-04-29 00:00:00         4.000000       3.880000
# ...

# %%
sns.boxplot(x = 'Profit (₹)' , data = df)
# Out:
# <Axes: xlabel='Profit (₹)'>

# %%
Q1 = df['Profit (₹)'].quantile(0.25)
Q3 = df['Profit (₹)'].quantile(0.75)
IQR = Q3 - Q1
lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

# %%
df['Profit (₹)'] = np.clip(df['Profit (₹)'], lower ,upper)

# %%
sns.boxplot(x = 'Profit (₹)' , data = df)
# Out:
# <Axes: xlabel='Profit (₹)'>

# %%
print(lower_limit)
print(upper_limit)
# Out:
# -9049.092499999999
# 19706.6075

# %%
np.clip(df['Profit (₹)'], lower_limit ,upper_limit)
# Out:
# 0          995.0500
# 1         1667.8200
# 2         6973.0800
# 3         2069.8200
# 4         8868.8300
#             ...
# 39995     1252.2700
# 39996    11616.1100
# 39997    15135.7300
# 39998     1909.6300
# 39999    19706.6075
# Name: Profit (₹), Length: 40000, dtype: float64

# %%
sns.boxplot(x = 'Profit (₹)' , data = df)
# Out:
# <Axes: xlabel='Profit (₹)'>

# %%
df['Profit (₹)'].max()
# Out:
# np.float64(19706.6075)

# %%
Q1 = df['Total Amount (₹)'].quantile(0.25)
Q3 = df['Total Amount (₹)'].quantile(0.75)
IQR = Q3 - Q1
lower_limit = Q1 - 1.5 * IQR
upper_limit = Q3 + 1.5 * IQR

# %%
print(lower_limit)
print(upper_limit)
# Out:
# -50060.897500000014
# 120756.84250000001

# %%
df['Total Amount (₹)'] = np.clip(df['Total Amount (₹)'], lower_limit ,upper_limit)

# %%
#z score need to be done for understanding
#upper method is capping 
#and percentile is for capping

# %%
sns.boxplot(x ='Total Amount (₹)' , data = df)
# Out:
# <Axes: xlabel='Total Amount (₹)'>

# %%
sns.boxplot(x = 'Profit (₹)' , data = df)
# Out:
# <Axes: xlabel='Profit (₹)'>

# %%
'''lower_limit = df['Profit (₹)'].quantile(0.05)
upper_limit = df['Profit (₹)'].quantile(0.95)
df['Profit (₹)'] = np.where(df['Profit (₹)'] < lower_limit, lower_limit , 
                        np.where(df['Profit (₹)'] > upper_limit ,upper_limit, df['Profit (₹)']))'''

# %%
sns.boxplot(x = 'Total Amount (₹)' , data = df)
# Out:
# <Axes: xlabel='Total Amount (₹)'>

# %%
df['Profit (₹)'].skew()
# Out:
# np.float64(0.3315583634354766)

# %%
df['Profit (₹)'].plot(kind = 'kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Total Amount (₹)'].skew()
# Out:
# np.float64(0.9078690501299203)

# %%
df['Total Amount (₹)'].plot(kind = 'kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Total Amount (₹)'].kurt()
# Out:
# np.float64(-0.012248025017118636)

# %%
df['Profit (₹)'].kurt()
# Out:
# np.float64(0.48400092319060173)

# %%
from sklearn.preprocessing import PowerTransformer
pt_yeo_tot = PowerTransformer(method = 'yeo-johnson')
transformed_tot = pt_yeo_tot.fit_transform(df['Total Amount (₹)'].values.reshape(-1,1))

# %%
df['Total Amount (₹)'].plot(kind = 'kde')
# Out:
# <Axes: ylabel='Density'>

# %%
from sklearn.preprocessing import PowerTransformer
pt_yeo_profit = PowerTransformer(method = 'yeo-johnson')
transformed_profit = pt_yeo_profit.fit_transform(df['Profit (₹)'].values.reshape(-1,1))

# %%
df['Profit (₹)'].plot(kind = 'kde')
# Out:
# <Axes: ylabel='Density'>

# %%
transformed_2 = pt_yeo_profit.fit_transform(df['Profit (₹)'].values.reshape(-1,1))

# %%
df['Profit (₹)'].plot(kind = 'kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Profit (₹)'].skew()
# Out:
# np.float64(1.1253615710645555)

# %%
df.to_csv('Cleaned_Data.csv' , index = False)

# %%
df.to_excel('Cleaned_excel_sales.xlsx' , index = False)

# %%
pip install openpyxl
# Out:
# ...
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Using cached et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# ...
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
# ...

# %%
sns.heatmap(df.select_dtypes(include = ['int64','float64']).corr() , annot = True)
plt.show()
